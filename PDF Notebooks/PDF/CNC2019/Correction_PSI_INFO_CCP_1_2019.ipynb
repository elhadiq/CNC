# %% [markdown]
# **CPGE: Lycée Moulay Youssef Rabat**\
# **Prof: El HADIQ Zouhair**\
# **Année Scolaire: 2022/2023**

# %%
import numpy as np
import sympy as sy

# %% [markdown]
# # Intelligence Artificielle - Application en médecine

# %% [markdown]
# ## Partie II - Analyse des données

# %% [markdown]
# ### Les requêtes SQL

# %% [markdown]
# **Q1. Écrire une requête SQL permettant d’extraire les identifiants des patients ayant une « hernie
# discale ».**

# %% [markdown]
# **R1**

# %%
SELECT idpatient FROM MEDICAL WHERE etat= "hernie discale"

# %% [markdown]
# **Q2. Écrire une requête SQL permettant d’extraire les noms et prénoms des patients atteints de
# « spondylolisthésis ».**

# %% [markdown]
# **R2**

# %%
SELECT nom, prenom FROM PATIENT JOINT MEDICAL ON PATIENT.id=MEDICAL.idpatient where etat= "spondylolisthésis"

# %% [markdown]
# **Q3. Écrire une requête SQL permettant d’extraire chaque état et le nombre de patients pour chaque
# état.**

# %% [markdown]
# **R3**

# %%
SELECT etat,COUNT(distinct idpatient) as nombreDePatients from MEDICAL group by etat

# %% [markdown]
# **Q4. Citer un intérêt d'utiliser la bibliothèque de calcul numérique Numpy quand les tableaux sont
# de grande taille**

# %% [markdown]
# **R4**: Ils sont facile à manupiler et le temps de calcule de chaque opération est assez réduit.

# %% [markdown]
# **Q5. Déterminer la quantité de mémoire totale en Mo (1 Mo = 1 000 000 octets) nécessaire pour stocker le tableau et le vecteur des données si N = 100 000. On supposera que les données sont représentées en suivant la norme usuelle IEEE 754.**

# %% [markdown]
# **R5**:

# %%
N=1000000
quantité=(6*N*32+8*N)/(8*1000000)
print("La quantité de mémoire nécessaire est {} Mo".format(quantité))
# Out:
# La quantité de mémoire nécessaire est 25.0 Mo
