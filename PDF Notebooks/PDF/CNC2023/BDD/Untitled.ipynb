# %%
import sqlite3
import pandas as pd
con=sqlite3.connect("dbtest.db")
sql=lambda requete:pd.read_sql_query(requete,con)

# %%
sql("""select * from Personnes
""")
# Out:
# Empty DataFrame
# Columns: [PersonID, LastName]
# Index: []

# %%
sql("""Insert Into Personnes Values (1,'Ahmed');""")
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/io/sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# IntegrityError: UNIQUE constraint failed: Personnes.PersonID
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sql("""Insert Into Personnes Values (1,'Ahmed');""")
#
# Cell In[1], line 4, in <lambda>(requete)
#       2 import pandas as pd
#       3 con=sqlite3.connect("dbtest.db")
# ----> 4 sql=lambda requete:pd.read_sql_query(requete,con)
#
# ...
